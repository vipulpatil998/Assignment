# %%
# !pip install html5lib

# %%
import pandas as pd
from pandas import read_html
import html5lib

# %%
url = "file:///C:/Users/vipul%20patil/OneDrive/Desktop/Personel%20Projects/pdf%20extracter%20using%20python/Internshala%20Assignment%20Feb2022/59997.html"

# %%
tables_list = pd.io.html.read_html(url)

# %%
tables_list
# Out:
# [                                                   0
#  0  .highlight { background-color: yellow };  func...,
#                                                     0
#  0  FULL DETAILS (Read-only) -> Click Here to Crea...,
#                                                      0  \
#  0                                         CTRI Number
#  1                                   Last Modified On:
#  2                                Post Graduate Thesis
#  3                                       Type of Trial
#  4                                       Type of Study
#  5                                        Study Design
#  6                               Public Title of Study
#  7                           Scientific Title of Study
#  8                                       Trial Acronym
#  9                                Secondary IDs if Any
#  10  Details of Principal Investigator or overall T...
#  11          Details of Contact PersonScientific Query
# ...

# %%
my_list = tables_list[2]

# %%
my_list
# Out:
#                                                     0  \
# 0                                         CTRI Number
# 1                                   Last Modified On:
# 2                                Post Graduate Thesis
# 3                                       Type of Trial
# 4                                       Type of Study
# 5                                        Study Design
# 6                               Public Title of Study
# 7                           Scientific Title of Study
# 8                                       Trial Acronym
# 9                                Secondary IDs if Any
# 10  Details of Principal Investigator or overall T...
# 11          Details of Contact PersonScientific Query
# 12              Details of Contact PersonPublic Query
# 13             Source of Monetary or Material Support
# 14                                    Primary Sponsor
# 15                       Details of Secondary Sponsor
# ...

# %%
my_list[1][0]
# Out:
# 'CTRI/2021/09/036254\xa0[Registered on: 06/09/2021] Trial Registered Prospectively'

# %%
from openpyxl import Workbook, load_workbook

# %%
wb = load_workbook('Data Format Feb2022.xlsx')
ws = wb.active

# %%
ws['A4'].value = my_list[1][0]
ws['B4'].value = my_list[1][1]
ws['C4'].value = my_list[1][2]
ws['D4'].value = my_list[1][3]
ws['E4'].value = my_list[1][4]
ws['F4'].value = my_list[1][5]
ws['G4'].value = my_list[1][6]
ws['H4'].value = my_list[1][7]
ws['I4'].value = my_list[1][8]


ws['AG4'].value = my_list[1][13]
ws['AH4'].value = my_list[1][14]
ws['AI4'].value = my_list[1][15]
ws['AJ4'].value = my_list[1][16]
ws['AK4'].value = my_list[1][17]
ws['AR4'].value = my_list[1][18]
ws['AS4'].value = my_list[1][19]
ws['AT4'].value = my_list[1][20]
ws['AU4'].value = my_list[1][21]
ws['AV4'].value = my_list[1][22]
ws['AW4'].value = my_list[1][23]
ws['AX4'].value = my_list[1][24]
ws['AY4'].value = my_list[1][25]
ws['AZ4'].value = my_list[1][26]
ws['BA4'].value = my_list[1][27]
ws['BB4'].value = my_list[1][28]
ws['BC4'].value = my_list[1][29]

# %%
my_list = tables_list[3]

# %%
my_list
# Out:
#               0           1
# 0  Secondary ID  Identifier
# 1           NIL         NIL

# %%
my_list[0][1]
# Out:
# 'NIL'

# %%
ws['J4'].value = my_list[0][1]

# %%
my_list = tables_list[4]
my_list
# Out:
#              0                                                  1
# 0         Name                                  Manickam Ponnaiah
# 1  Designation                                        Scientist E
# 2  Affiliation          ICMR - National Institute of Epidemiology
# 3      Address  Room Number 127, th floor, ICMR-NIE, R127, TNH...
# 4        Phone                                         9444030527
# 5          Fax                                                NaN
# 6        Email                                manickam@nie.gov.in

# %%
my_list[1][4]
# Out:
# '9444030527'

# %%
ws['L4'].value = my_list[1][0]
ws['M4'].value = my_list[1][1]
ws['N4'].value = my_list[1][2]
ws['O4'].value = my_list[1][3]
ws['P4'].value = my_list[1][4]
ws['Q4'].value = 'NA'
ws['R4'].value = my_list[1][6]

# %%
my_list = tables_list[5]
my_list
# Out:
#              0                                                  1
# 0         Name                                  Manickam Ponnaiah
# 1  Designation                                        Scientist E
# 2  Affiliation          ICMR - National Institute of Epidemiology
# 3      Address  Room Number 127, th floor, ICMR-NIE, R127, TNH...
# 4        Phone                                         9444030527
# 5          Fax                                                NaN
# 6        Email                                manickam@nie.gov.in

# %%
ws['S4'].value = my_list[1][0]
ws['T4'].value = my_list[1][1]
ws['U4'].value = my_list[1][2]
ws['V4'].value = my_list[1][3]
ws['W4'].value =  my_list[1][4]
ws['X4'].value = 'NA'
ws['Y4'].value = my_list[1][6]

# %%
my_list = tables_list[6]
my_list
# Out:
#              0                                                  1
# 0         Name                                  Manickam Ponnaiah
# 1  Designation                                        Scientist E
# 2  Affiliation          ICMR - National Institute of Epidemiology
# 3      Address  Room Number 127, th floor, ICMR-NIE, R127, TNH...
# 4        Phone                                         9444030527
# 5          Fax                                                NaN
# 6        Email                                manickam@nie.gov.in

# %%
ws['Z4'].value = my_list[1][0]
ws['AA4'].value = my_list[1][1]
ws['AB4'].value = my_list[1][2]
ws['AC4'].value = my_list[1][3]
ws['AD4'].value = my_list[1][4]
ws['AE4'].value = 'NA'
ws['AF4'].value = my_list[1][6]

# %%
my_list = tables_list[10]
my_list
# Out:
#                                  0  \
# 0                 No of Sites = 29
# 1   Name of Principal Investigator
# 2                  Dr Parul Sharma
# 3                 Dr Vaibhav Saini
# 4         Dr Pradipta Kumar Parida
# 5                        Dr Satish
# 6              Dr Amit Kumar Tyagi
# 7                Dr Suresh Kumar D
# 8         Dr Bhagirathsinh D Pamar
# 9              Dr Kajal Srivastava
# 10                        Dr Sunil
# 11                Dr Surendra Babu
# 12                   Dr Simmi Dube
# 13                     Dr Niharika
# 14            Dr Rahul Kumar Bagla
# 15            Dr Renuka S Melkundi
# 16        Dr Anjan Jyothi Talukdar
# 17                       Dr Gaurav
# 18             Dr Praveen Kulkarni
# 19                   Dr Puhalenthi
# 20                   Dr Subhashree
# 21                     Dr Devaraja
# 22                  Dr Seetharaman
# 23                        Dr Priya
# 24                      Dr Nandini
# ...

# %%
my_list[2][2]
# Out:
# 'Department of Community Medicine, Gujarat Medical Education & Research Society Medical College Gandhinag, New Building, Medical College, Civil Hospital Campus, Sector-1, Ahmedabad, Gujarat 382012AhmadabadGUJARAT'

# %%
ws['AK4'].value = '1'
ws['AL4'].value = my_list[0][2]
ws['AM4'].value = my_list[1][2]
ws['AN4'].value = my_list[2][2]
ws['AO4'].value = my_list[3][2]
ws['AP4'].value = my_list[3][2]
ws['AQ4'].value = my_list[3][2]

# %%
ws['BC4'].value = '480'
ws['I4'].value = 'NA'

# %%
wb.save('Data Format Feb2022.xlsx')
