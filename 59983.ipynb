# %%
# !pip install html5lib

# %%
import pandas as pd
from pandas import read_html
import html5lib

# %%
url = "file:///C:/Users/vipul%20patil/OneDrive/Desktop/Personel%20Projects/pdf%20extracter%20using%20python/Internshala%20Assignment%20Feb2022/59983.html"

# %%
tables_list = pd.io.html.read_html(url)

# %%
tables_list
# Out:
# [                                                   0
#  0  .highlight { background-color: yellow };  func...,
#                                                     0
#  0  FULL DETAILS (Read-only) -> Click Here to Crea...,
#                                                      0  \
#  0                                         CTRI Number
#  1                                   Last Modified On:
#  2                                Post Graduate Thesis
#  3                                       Type of Trial
#  4                                       Type of Study
#  5                                        Study Design
#  6                               Public Title of Study
#  7                           Scientific Title of Study
#  8                                       Trial Acronym
#  9                                Secondary IDs if Any
#  10  Details of Principal Investigator or overall T...
#  11          Details of Contact PersonScientific Query
# ...

# %%
my_list = tables_list[2]

# %%
my_list
# Out:
#                                                     0  \
# 0                                         CTRI Number
# 1                                   Last Modified On:
# 2                                Post Graduate Thesis
# 3                                       Type of Trial
# 4                                       Type of Study
# 5                                        Study Design
# 6                               Public Title of Study
# 7                           Scientific Title of Study
# 8                                       Trial Acronym
# 9                                Secondary IDs if Any
# 10  Details of Principal Investigator or overall T...
# 11          Details of Contact PersonScientific Query
# 12              Details of Contact PersonPublic Query
# 13             Source of Monetary or Material Support
# 14                                    Primary Sponsor
# 15                       Details of Secondary Sponsor
# ...

# %%
my_list[1][0]
# Out:
# 'CTRI/2021/08/036079\xa0[Registered on: 31/08/2021] Trial Registered Prospectively'

# %%
from openpyxl import Workbook, load_workbook

# %%
wb = load_workbook('Data Format Feb2022.xlsx')
ws = wb.active

# %%
ws['A3'].value = my_list[1][0]
ws['B3'].value = my_list[1][1]
ws['C3'].value = my_list[1][2]
ws['D3'].value = my_list[1][3]
ws['E3'].value = my_list[1][4]
ws['F3'].value = my_list[1][5]
ws['G3'].value = my_list[1][6]
ws['H3'].value = my_list[1][7]
ws['I3'].value = my_list[1][8]
ws['J3'].value = my_list[1][9]

ws['AG3'].value = my_list[1][13]
ws['AH3'].value = my_list[1][14]
ws['AI3'].value = my_list[1][15]
ws['AJ3'].value = my_list[1][16]
ws['AK3'].value = my_list[1][17]
ws['AR3'].value = my_list[1][18]
ws['AS3'].value = my_list[1][19]
ws['AT3'].value = my_list[1][20]
ws['AU3'].value = my_list[1][21]
ws['AV3'].value = my_list[1][22]
ws['AW3'].value = my_list[1][23]
ws['AX3'].value = my_list[1][24]
ws['AY3'].value = my_list[1][25]
ws['AZ3'].value = my_list[1][26]
ws['BA3'].value = my_list[1][27]
ws['BB3'].value = my_list[1][28]
ws['BC3'].value = my_list[1][29]

# %%
my_list = tables_list[3]

# %%
my_list
# Out:
#               0           1
# 0  Secondary ID  Identifier
# 1           NIL         NIL

# %%
my_list[0][1]
# Out:
# 'NIL'

# %%
ws['J3'].value = my_list[0][1]

# %%
my_list = tables_list[4]
my_list
# Out:
#              0                                                  1
# 0         Name                                        Nikhat Naaz
# 1  Designation                                         PG student
# 2  Affiliation                         MS Ramaiah Medical College
# 3      Address  Department of Physiotherapy MS Ramaiah Nagar, ...
# 4        Phone                                         8197324719
# 5          Fax                                                NaN
# 6        Email                               nikinaaz98@gmail.com

# %%
my_list[1][4]
# Out:
# '8197324719'

# %%
ws['L3'].value = my_list[1][0]
ws['M3'].value = my_list[1][1]
ws['N3'].value = my_list[1][2]
ws['O3'].value = my_list[1][3]
ws['P3'].value = my_list[1][4]
ws['Q3'].value = 'NA'
ws['R3'].value = my_list[1][6]

# %%
my_list = tables_list[5]
my_list
# Out:
#              0                                                  1
# 0         Name                                     Dr Kirti Joshi
# 1  Designation                                Assistant professor
# 2  Affiliation                         MS Ramaiah Medical College
# 3      Address  MS Ramaiah Nagar, MSRIT Post, BangaloreBangalo...
# 4        Phone                                         9686851063
# 5          Fax                                                NaN
# 6        Email                             kirtijoshi@msrmc.ac.in

# %%
ws['S3'].value = my_list[1][0]
ws['T3'].value = my_list[1][1]
ws['U3'].value = my_list[1][2]
ws['V3'].value = my_list[1][3]
ws['W3'].value =  my_list[1][4]
ws['X3'].value = 'NA'
ws['Y3'].value = my_list[1][6]

# %%
my_list = tables_list[6]
my_list
# Out:
#              0                                                  1
# 0         Name                                        Nikhat Naaz
# 1  Designation                                         PG student
# 2  Affiliation                         MS Ramaiah Medical College
# 3      Address  Department of Physiotherapy, MS Ramaiah Nagar,...
# 4        Phone                                         8197324719
# 5          Fax                                                NaN
# 6        Email                               nikinaaz98@gmail.com

# %%
ws['Z3'].value = my_list[1][0]
ws['AA3'].value = my_list[1][1]
ws['AB3'].value = my_list[1][2]
ws['AC3'].value = my_list[1][3]
ws['AD3'].value = my_list[1][4]
ws['AE3'].value = 'NA'
ws['AF3'].value = my_list[1][6]

# %%
my_list = tables_list[10]
my_list
# Out:
#                                 0                           1  \
# 0                 No of Sites = 1             No of Sites = 1
# 1  Name of Principal Investigator                Name of Site
# 2                     Nikhat Naaz  MS Ramaiah Medical College
#
#                                                    2  \
# 0                                    No of Sites = 1
# 1                                       Site Address
# 2  Department of Physiotherapy, MS Ramaiah Nagar,...
#
#                                 3
# 0                 No of Sites = 1
# 1                 Phone/Fax/Email
# 2  8197324719nikinaaz98@gmail.com

# %%
my_list[2][2]
# Out:
# 'Department of Physiotherapy, MS Ramaiah Nagar, MSRIT Post, Bangalore 560054. BangaloreKARNATAKA'

# %%
ws['AK3'].value = my_list[0][0][14]
ws['AL3'].value = my_list[0][2]
ws['AM3'].value = my_list[1][2]
ws['AN3'].value = my_list[2][2]
ws['AO3'].value = my_list[3][2]
ws['AP3'].value = my_list[3][2]
ws['AQ3'].value = my_list[3][2]

# %%
ws['BC3'].value = '96'

# %%
wb.save('Data Format Feb2022.xlsx')
