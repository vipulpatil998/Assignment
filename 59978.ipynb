# %%
# !pip install html5lib

# %%
import pandas as pd
from pandas import read_html
import html5lib

# %%
url = "file:///C:/Users/vipul%20patil/OneDrive/Desktop/Personel%20Projects/pdf%20extracter%20using%20python/Internshala%20Assignment%20Feb2022/59978.html"

# %%
tables_list = pd.io.html.read_html(url)

# %%
tables_list
# Out:
# [                                                   0
#  0  .highlight { background-color: yellow };  func...,
#                                                     0
#  0  FULL DETAILS (Read-only) -> Click Here to Crea...,
#                                                      0  \
#  0                                         CTRI Number
#  1                                   Last Modified On:
#  2                                Post Graduate Thesis
#  3                                       Type of Trial
#  4                                       Type of Study
#  5                                        Study Design
#  6                               Public Title of Study
#  7                           Scientific Title of Study
#  8                                       Trial Acronym
#  9                                Secondary IDs if Any
#  10  Details of Principal Investigator or overall T...
#  11          Details of Contact PersonScientific Query
# ...

# %%
my_list = tables_list[2]

# %%
my_list
# Out:
#                                                     0  \
# 0                                         CTRI Number
# 1                                   Last Modified On:
# 2                                Post Graduate Thesis
# 3                                       Type of Trial
# 4                                       Type of Study
# 5                                        Study Design
# 6                               Public Title of Study
# 7                           Scientific Title of Study
# 8                                       Trial Acronym
# 9                                Secondary IDs if Any
# 10  Details of Principal Investigator or overall T...
# 11          Details of Contact PersonScientific Query
# 12              Details of Contact PersonPublic Query
# 13             Source of Monetary or Material Support
# 14                                    Primary Sponsor
# 15                       Details of Secondary Sponsor
# ...

# %%
my_list[1][0]
# Out:
# 'CTRI/2021/09/036162\xa0[Registered on: 02/09/2021] Trial Registered Prospectively'

# %%
from openpyxl import Workbook, load_workbook

# %%
wb = load_workbook('Data Format Feb2022.xlsx')
ws = wb.active

# %%
ws['A2'].value = my_list[1][0]
ws['B2'].value = my_list[1][1]
ws['C2'].value = my_list[1][2]
ws['D2'].value = my_list[1][3]
ws['E2'].value = my_list[1][4]
ws['F2'].value = my_list[1][5]
ws['G2'].value = my_list[1][6]
ws['H2'].value = my_list[1][7]
ws['I2'].value = my_list[1][8]
ws['J2'].value = my_list[1][9]
ws['K2'].value = my_list[1][10]
ws['L2'].value = my_list[1][10]
ws['M2'].value = my_list[1][10]
ws['N2'].value = my_list[1][10]
ws['O2'].value = my_list[1][10]
ws['P2'].value = my_list[1][10]
ws['Q2'].value = my_list[1][10]
ws['R2'].value = my_list[1][10]
ws['S2'].value = my_list[1][11]
ws['T2'].value = my_list[1][11]
ws['U2'].value = my_list[1][11]
ws['V2'].value = my_list[1][11]
ws['W2'].value = my_list[1][11]
ws['X2'].value = my_list[1][11]
ws['Y2'].value = my_list[1][11]
ws['Z2'].value = my_list[1][12]
ws['AA2'].value = my_list[1][12]
ws['AB2'].value = my_list[1][12]
ws['AC2'].value = my_list[1][12]
ws['AD2'].value = my_list[1][12]
ws['AE2'].value = my_list[1][12]
ws['AF2'].value = my_list[1][12]
ws['AG2'].value = my_list[1][13]
ws['AH2'].value = my_list[1][14]
ws['AI2'].value = my_list[1][15]
ws['AJ2'].value = my_list[1][16]
ws['AK2'].value = my_list[1][17]
ws['AR2'].value = my_list[1][18]
ws['AS2'].value = my_list[1][19]
ws['AT2'].value = my_list[1][20]
ws['AU2'].value = my_list[1][21]
ws['AV2'].value = my_list[1][22]
ws['AW2'].value = my_list[1][23]
ws['AX2'].value = my_list[1][24]
ws['AY2'].value = my_list[1][25]
ws['AZ2'].value = my_list[1][26]
ws['BA2'].value = my_list[1][27]
ws['BB2'].value = my_list[1][28]
ws['BC2'].value = my_list[1][29]

# %%
wb.save('Data Format Feb2022.xlsx')
